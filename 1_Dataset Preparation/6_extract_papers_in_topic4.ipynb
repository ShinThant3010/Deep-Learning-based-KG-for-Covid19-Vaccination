# %% [markdown]
# ### 6. Create filtered corpus with papers from selected topic number

# %%
import pandas as pd

# %%
df = pd.read_csv('dataset_with_topic.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  \
# 0           0             4               4              4246
# 1           1        393220          483203            736911
# 2           2             6               6              4248
# 3           3        393222          483205            736914
# 4           4        262152          302536            481315
#
#                                                title  \
# 0  Synthetic carbohydrate-based vaccines: challen...
# 1    Retinal Hemorrhage after SARS-CoV-2 Vaccination
# 2  Identification of antigens presented by MHC fo...
# 3  Next-Generation Serology by Mass Spectrometry:...
# 4  Pre-vaccination Antibody Titers Against Season...
#
#                                             abstract publish_time  \
# 0  glycoconjugate vaccines based on bacterial cap...   2020-01-03
# 1  to report retinal vein occlusion (rvo) and age...   2021-12-05
# 2  mycobacterium tuberculosis (m.tb) is responsib...   2020-01-03
# ...

# %%
topic4_df = df.loc[df['Selected Topic'] == 'Topic 4']

# %%
topic4_df.head()
# Out:
#     Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  \
# 1            1        393220          483203            736911
# 4            4        262152          302536            481315
# 6            6             7               7              4249
# 11          11        131091          131740            226639
# 15          15        131100          131749            226650
#
#                                                 title  \
# 1     Retinal Hemorrhage after SARS-CoV-2 Vaccination
# 4   Pre-vaccination Antibody Titers Against Season...
# 6         Imaging of tumour response to immunotherapy
# 11  Outcomes of Patients with Budd-Chiari Syndrome...
# 15  Multifactorial analysis of cancer patients' wi...
#
#                                              abstract publish_time  \
# 1   to report retinal vein occlusion (rvo) and age...   2021-12-05
# 4   background the prospective assessment of sars-...         2021
# ...

# %%
topic4_df.to_csv('topic4_dataset.csv')
